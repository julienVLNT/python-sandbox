# %%
# !python --version
# Out:
# Python 3.7.13

# %% [markdown]
# **Julien VALENTIN**, **mars 2022** d'après
#
# > [Machine learning in Python with scikit-learn](https://www.fun-mooc.fr/fr/cours/machine-learning-python-scikit-learn/) d'I.N.R.I.A sur [F.U.N](https://www.fun-mooc.fr/fr/).

# %% [markdown]
# # Import et lecture d'un jeu de données

# %% [markdown]
# - [page de présentation du *Palmer Archipelago (Antarctica) Penguin Data*](https://cloud.r-project.org/web/packages/palmerpenguins/index.html)

# %% [markdown]
# ### Téléchargement

# %%
# !wget -O sample_data/palmerpenguins.tar.gz https://cloud.r-project.org/src/contrib/palmerpenguins_0.1.0.tar.gz
# Out:
# --2022-03-28 11:22:17--  https://cloud.r-project.org/src/contrib/palmerpenguins_0.1.0.tar.gz
# Resolving cloud.r-project.org (cloud.r-project.org)... 108.157.162.43, 108.157.162.119, 108.157.162.110, ...
# Connecting to cloud.r-project.org (cloud.r-project.org)|108.157.162.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2987721 (2.8M) [application/x-gzip]
# Saving to: ‘sample_data/palmerpenguins.tar.gz’
#
# sample_data/palmerp 100%[===================>]   2.85M  --.-KB/s    in 0.1s
#
# 2022-03-28 11:22:17 (21.9 MB/s) - ‘sample_data/palmerpenguins.tar.gz’ saved [2987721/2987721]

# %% [markdown]
# ### Extraction de l'archive

# %%
# !tar -xvzf sample_data/palmerpenguins.tar.gz
# Out:
# palmerpenguins/
# palmerpenguins/NAMESPACE
# palmerpenguins/README.md
# palmerpenguins/data/
# palmerpenguins/data/penguins.R
# palmerpenguins/man/
# palmerpenguins/man/path_to_file.Rd
# palmerpenguins/man/figures/
# palmerpenguins/man/figures/README-flipper-bill-1.png
# palmerpenguins/man/figures/README-mass-flipper-1.png
# palmerpenguins/man/figures/logo.png
# palmerpenguins/man/figures/palmerpenguins.png
# palmerpenguins/man/figures/culmen_depth.png
# palmerpenguins/man/figures/README-flipper-hist-1.png
# palmerpenguins/man/figures/lter_penguins.png
# palmerpenguins/man/palmerpenguins-package.Rd
# palmerpenguins/man/penguins_raw.Rd
# palmerpenguins/man/penguins.Rd
# palmerpenguins/DESCRIPTION
# palmerpenguins/R/
# palmerpenguins/R/sysdata.rda
# palmerpenguins/R/palmerpenguins-package.R
# palmerpenguins/R/penguins_raw.R
# palmerpenguins/R/path-to-file.R
# palmerpenguins/R/penguins.R
# palmerpenguins/MD5
# palmerpenguins/inst/
# palmerpenguins/inst/extdata/
# ...

# %% [markdown]
# ### lecture des données : `penguins.csv`

# %%
import pandas

# %%
dataset = pandas.read_csv("palmerpenguins/inst/extdata/penguins.csv")

# %% [markdown]
# ### Aperçu et exploration

# %%
dataset.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %%
dataset['species'].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
dataset['island'].value_counts()
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64

# %%
dataset['sex'].value_counts()
# Out:
# male      168
# female    165
# Name: sex, dtype: int64

# %%
dataset.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
dataset[["bill_length_mm", "bill_depth_mm"]].hist(figsize=(10, 5));

# %% [markdown]
# ### Exploration graphique

# %%
import seaborn

# %%
seaborn.pairplot(dataset[["bill_length_mm", "bill_depth_mm", "species"]], height=4, hue="species");
